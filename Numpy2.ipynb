# %%
import pandas as pd

# %%
df = pd.read_csv("/content/forbes billionaire list cleaned.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of         rank                      name  net_worth (in billion $)   age  \
# 0        1.0  Bernard Arnault & family                     211.0  74.0
# 1        2.0                 Elon Musk                     180.0  51.0
# 2        3.0                Jeff Bezos                     114.0  59.0
# 3        4.0             Larry Ellison                     107.0  78.0
# 4        5.0            Warren Buffett                     106.0  92.0
# ...      ...                       ...                       ...   ...
# 2652  2540.0               Scott Smith                       1.0  73.0
# 2653  2540.0    Wen Pengcheng & family                       1.0  60.0
# 2654  2540.0              Neerja Sethi                       1.0  68.0
# 2655     NaN                       NaN                       NaN   NaN
# 2656     NaN                       NaN                       NaN   NaN
#
#      country / territory                      source               industry
# 0                 France                        LVMH       Fashion & Retail
# 1          United States               Tesla, SpaceX             Automotive
# 2          United States                      Amazon             Technology
# 3          United States                      Oracle             Technology
# 4          United States          Berkshire Hathaway  Finance & Investments
# ...                  ...                         ...                    ...
# 2652       United States             Cloud computing             Technology
# 2653               China                Agribusiness        Food & Beverage
# 2654       United States  IT consulting, outsourcing             Technology
# 2655                 NaN                         NaN                    NaN
# 2656                 NaN                         NaN                    NaN
#
# [2657 rows x 7 columns]>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of         rank                      name  net_worth (in billion $)   age  \
# 0        1.0  Bernard Arnault & family                     211.0  74.0
# 1        2.0                 Elon Musk                     180.0  51.0
# 2        3.0                Jeff Bezos                     114.0  59.0
# 3        4.0             Larry Ellison                     107.0  78.0
# 4        5.0            Warren Buffett                     106.0  92.0
# ...      ...                       ...                       ...   ...
# 2652  2540.0               Scott Smith                       1.0  73.0
# 2653  2540.0    Wen Pengcheng & family                       1.0  60.0
# 2654  2540.0              Neerja Sethi                       1.0  68.0
# 2655     NaN                       NaN                       NaN   NaN
# 2656     NaN                       NaN                       NaN   NaN
#
#      country / territory                      source               industry
# 0                 France                        LVMH       Fashion & Retail
# 1          United States               Tesla, SpaceX             Automotive
# 2          United States                      Amazon             Technology
# 3          United States                      Oracle             Technology
# 4          United States          Berkshire Hathaway  Finance & Investments
# ...                  ...                         ...                    ...
# 2652       United States             Cloud computing             Technology
# 2653               China                Agribusiness        Food & Beverage
# 2654       United States  IT consulting, outsourcing             Technology
# 2655                 NaN                         NaN                    NaN
# 2656                 NaN                         NaN                    NaN
#
# [2657 rows x 7 columns]>

# %%
df.shape
# Out:
# (2657, 7)

# %%
df.columns
# Out:
# Index(['rank', 'name', 'net_worth (in billion $)', 'age',
#        'country / territory', 'source', 'industry'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                            count         mean         std   min    25%  \
# rank                      2655.0  1296.225989  743.537056   1.0  659.0
# net_worth (in billion $)  2655.0     4.603315    9.810173   1.0    1.5
# age                       2588.0    65.129444   13.255592  18.0   56.0
#
#                              50%     75%     max
# rank                      1312.0  1905.0  2540.0
# net_worth (in billion $)     2.3     4.2   211.0
# age                         65.0    75.0   101.0

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
df.hist(figsize=(10,15))
# Out:
# <ipython-input-11-27d823c1454d>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# array([[<Axes: title={'center': 'rank'}>,
#         <Axes: title={'center': 'net_worth (in billion $)'}>],
#        [<Axes: title={'center': 'age'}>, <Axes: >]], dtype=object)

# %%
import seaborn as sns
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), annot=True, cmap="winter")
# Out:
# <ipython-input-13-22be7849bc98>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="winter")
# <Axes: >
